# %% [markdown]
# ## `Q-1:` Rectangle Class
# 1. Write a Rectangle class in Python language, allowing you to build a rectangle with length and width attributes.
#
# 2. Create a Perimeter() method to calculate the perimeter of the rectangle and a Area() method to calculate the area of ​​the rectangle.
#
# 3. Create a method display() that display the length, width, perimeter and area of an object created using an instantiation on rectangle class.

# %% [markdown]
# Eg.
# After making above classes and methods, on executing below code:-
# ```
# my_rectangle = Rectangle(3 , 4)
# my_rectangle.display()
# ```
#
# `Output:`
# ```
# The length of rectangle is:  3
# The width of rectangle is:  4
# The perimeter of rectangle is:  14
# The area of rectangle is:  12
# ```

# %%
# write your code here
class Rectangle:  
    def __init__(self,length,width):
        self.length = length
        self.width = width
        
    def Perimeter(self):
        return 2 * (self.length + self.width)
    
    def Area(self):
        return self.length * self.width
    
    def display(self):
        print(f"The length of rectangle is: {self.length}\nThe width of the rectangle: {self.width}")
        print(f"The perimter of rectangle is: {self.Perimeter()}\nThe area of rectangle: {self.Area()}")
        

    
my_rectangle = Rectangle(3,4)
my_rectangle.display()
# Out:
# The length of rectangle is: 3
# The width of the rectangle: 4
# The perimter of rectangle is: 14
# The area of rectangle: 12

# %%
# Testing
my_rectangle = Rectangle(3,4)
my_rectangle.display()    

print(35*"-")
your_rectangle = Rectangle(6,7)
your_rectangle.display()
# Out:
# The length of rectangle is: 3
# The width of the rectangle: 4
# The perimter of rectangle is: 14
# The area of rectangle: 12
# -----------------------------------
# The length of rectangle is: 6
# The width of the rectangle: 7
# The perimter of rectangle is: 26
# The area of rectangle: 42

# %% [markdown]
# ## `Q-2: Bank Class`
#
# 1. Create a Python class called `BankAccount` which represents a bank account, having as attributes: `accountNumber` (numeric type), `name` (name of the account owner as string type), `balance`.
# 2. Create a constructor with parameters: `accountNumber, name, balance`.
# 3. Create a `Deposit()` method which manages the deposit actions.
# 4. Create a `Withdrawal()` method  which manages withdrawals actions.
# 5. Create an `bankFees()` method to apply the bank fees with a percentage of 5% of the balance account.
# 6. Create a `display()` method to display account details.
# Give the complete code for the  BankAccount class.

# %% [markdown]
# Eg.
# After making above classes and methods, on executing below code:-
# ```
# newAccount = BankAccount(2178514584, "Mandy" , 2800)
#
# newAccount.Withdrawal(700)
#
# newAccount.Deposit(1000)
#
# newAccount.display()
# ```
#
# `Output:`
# ```
# Account Number :  2178514584
# Account Name :  Mandy
# Account Balance :  $3100
# ```

# %%
# write your code here
class BankAccount:
    def __init__(self, accountNumber, name, balance):
        self.accountNumber = accountNumber
        self.name = name
        self.balance = balance
        
    def Deposit(self, amount):
        if amount > 0:
            self.balance += amount
        
    def Withdrawal(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
        else:
            print("Invalid or insufficient funds")
                
    def bankFees(self):
        self.balance -= (self.balance * 0.05)
        
    def display(self):
        print(f"Account Number: {self.accountNumber}\nAccount Name: {self.name}\nAccount Balance: ${self.balance}")

# %%
# Testing
acc1 = BankAccount(123456,"Sohail",2800)
acc1.Withdrawal(700)
acc1.Deposit(1000)
acc1.display()
# Out:
# Account Number: 123456
# Account Name: Sohail
# Account Balance: $3100

# %% [markdown]
# ## `Q-3:Computation class`
#
# 1. Create a `Computation` class with a default constructor (without parameters) allowing to perform various calculations on integers numbers.
# 2. Create a method called `Factorial()` which allows to calculate the factorial of an integer n. Integer n as parameter for this method
#
# 3. Create a method called `naturalSum()` allowing to calculate the sum of the first n integers 1 + 2 + 3 + .. + n. Integer n as parameter for this method.
#
# 4. Create a method called `testPrime()` in  the Calculation class to test the primality of a given integer n, n is Prime or Not? Integer n as parameter for this method.
#
# 5. Create  a method called `testPrims()` allowing to test if two numbers are prime between them. Two integers are prime to one another if they have only `1` as their common divisor. Eg. 4 and 9 are prime to each other.
#
# 5. Create a `tableMult()` method which creates and displays the multiplication table of a given integer. Then create an `allTablesMult()` method to display all the integer multiplication tables 1, 2, 3, ..., 9.
#
# 6. Create a static `listDiv()` method that gets all the divisors of a given integer on new list called Ldiv. Create another `listDivPrim()` method that gets all the prime divisors of a given integer.

# %%
# write your code here
# write your code here
import math


class Computation:
    """Q-3: Performs various calculations on integer numbers."""

    def __init__(self):
        pass  # Default constructor (no parameters)

    # ── 1. Factorial ──
    def Factorial(self, n: int) -> int:
        result = 1                      # start with 1 (since 0! and 1! are both 1)
        for i in range(2, n + 1):      # multiply from 2 up to n
            result *= i
        return result

    # ── 2. Natural Sum ───
    def naturalSum(self, n: int) -> int:
        return sum(range(1, n + 1))    # adds all numbers from 1 to n

    # ── 3. Primality Test ──
    def testPrime(self, n: int) -> bool:
        if n < 2:                               # 0 and 1 are not prime
            return False
        if n == 2:                              # 2 is the only even prime
            return True
        if n % 2 == 0:                          # all other even numbers are not prime
            return False
        for i in range(3, int(math.sqrt(n)) + 1, 2):   # check odd divisors up to √n
            if n % i == 0:                              # found a divisor, not prime
                return False
        return True                             # no divisor found, it is prime

    # ── 4. Coprimality Test ──
    def testPrims(self, a: int, b: int) -> bool:
        # two numbers are coprime if their greatest common divisor is 1
        return math.gcd(abs(a), abs(b)) == 1

    # ── 5a. Multiplication Table ──
    def tableMult(self, n: int) -> None:
        print(f"--- Multiplication table of {n} ---")
        for i in range(1, 11):                  # loop from 1 to 10
            print(f"  {n} x {i:2d} = {n * i:3d}")

    # ── 5b. All Multiplication Tables 1-9 ──
    def allTablesMult(self) -> None:
        for i in range(1, 10):                  # loop through 1 to 9
            self.tableMult(i)                   # print table for each number
            print()                             # blank line between tables

    # ── 6a. List of All Divisors (static) ──
    @staticmethod
    def listDiv(n: int) -> list:
        Ldiv = []                               # empty list to store divisors
        n = abs(n)                              # work with positive value
        for i in range(1, n + 1):              # check every number from 1 to n
            if n % i == 0:                      # if i divides n with no remainder
                Ldiv.append(i)                  
        return Ldiv

    # ── 6b. List of Prime Divisors ──
    def listDivPrim(self, n: int) -> list:
        # get all divisors of n, then keep only the ones that are prime
        return [d for d in self.listDiv(n) if self.testPrime(d)]

# %%
c1 = Computation()
# c1.Factorial(5)
# c1.naturalSum(5)
# c1.testPrime(13)
# c1.testPrims(4,9)
# c1.tableMult(17)
# c1.allTablesMult()
# c1.listDiv(7)
c1.listDivPrim(10)
# Out:
# [2, 5]

# %% [markdown]
# ## `Q-4`: Build flashcard using class in Python.
#
# Build a flashcard using class in python. A flashcard is a card having information on both sides, which can be used as an aid in memoization. Flashcards usually have a question on one side and an answer on the other.
#
# **Example 1:**
#
# Approach:
#
# - Create a class named FlashCard.
# - Initialize dictionary fruits using __init__() method. Here you have to define fruit name as key and it's color as value. E.g., {"Banana": "yellow", "Strawberries": "pink"}
# - Now randomly choose a pair from fruits by using _random_ module and store the key in variable _fruit_ and _value_ in variable color.
# - Now prompt the user to answer the color of the randomly chosen fruit.
# - If correct print correct else print wrong.
#
# Output:
# ```bash
# welcome to fruit quiz
# What is the color of Strawberries
# pink
# Correct answer
# Enter 0, if you want to play again: 0
# What is the color of watermelon
# green
# Correct answer
# Enter 0, if you want to play again: 1
# ```

# %%
# write your code here
import random

class FlashCard:

    def __init__(self):
        # dictionary of fruits and their colors
        self.fruits = {
            "Banana": "yellow",
            "Strawberries": "pink",
            "Watermelon": "green",
            "Grapes": "purple",
            "Orange": "orange",
            "Apple": "red",
            "Blueberry": "blue",
            "Mango": "yellow"
        }

    def ask(self):
        # randomly pick a fruit from the dictionary
        fruit = random.choice(list(self.fruits.keys()))
        color = self.fruits[fruit]

        # ask the user the question
        answer = input(f"What is the color of {fruit}?\n").strip().lower()

        # check if the answer is correct
        if answer == color.lower():
            print("Correct answer")
        else:
            print(f"Wrong answer! The correct color is {color}")

    def play(self):
        print("Welcome to fruit quiz")

        while True:
            self.ask()

            # ask if the user wants to play again
            choice = input("Enter 0, if you want to play again: ").strip()

            if choice != "0":  # if user enters anything other than 0, stop
                print("Thanks for playing!")
                break

# %%
# run the game
card = FlashCard()
card.play()
# Out:
# Welcome to fruit quiz
# Correct answer
# Correct answer
# Wrong answer! The correct color is red
# Wrong answer! The correct color is purple
# Thanks for playing!

# %% [markdown]
# ## `Q-5:` Problem 5 based on OOP Python.
#
# TechWorld, a technology training center, wants to allocate courses for instructors. An instructor is identified by name, technology skills, experience and average feedback. An instructor is allocated a course, if he/she satisfies the below two conditions:
# - eligibility criteria:
#     - if experience is more than 3 years, average feedback should be 4.5 or more
#     - if experience is 3 years or less, average feedback should be 4 or more
# - he/she should posses the technology skill for the course
#
# Identify the class name and attributes to represent instructors. Write a Python program to implement the class chosen with its attributes and methods.
#
# **Note:**
# - Consider all instance variables to be private and methods to be public.
# - An instructor may have multiple technology skills, so consider instance variable, technology_skill to be a list.
# - *check_eligibility()*: Return true if eligibility criteria is satisfied by the instructor. Else, return false
# - *allocate_course(technology)*: Return true if the course which requires the given technology can be allocated to the instructor. Else, return false.
#
# Represent a few objects of the class, initialize instance variables using setter methods, invoke
# appropriate methods and test your program.

# %%
# write your code here
# Instructor class to represent a technology course instructor
class Instructor:
    def __init__(self):
        # Private instance variables
        self.__name = ""
        self.__technology_skills = []  # list of skills the instructor knows
        self.__experience = 0          # years of experience
        self.__avg_feedback = 0.0      # average feedback score out of 5

    # --- Setter Methods ---

    def set_name(self, name):
        self.__name = name

    def set_technology_skills(self, skills):
        self.__technology_skills = skills  # expects a list of skill strings

    def set_experience(self, experience):
        self.__experience = experience

    def set_avg_feedback(self, avg_feedback):
        self.__avg_feedback = avg_feedback

    # --- Getter Methods ---

    def get_name(self):
        return self.__name

    def get_technology_skills(self):
        return self.__technology_skills

    def get_experience(self):
        return self.__experience

    def get_avg_feedback(self):
        return self.__avg_feedback

    # Check if instructor meets the eligibility criteria
    def check_eligibility(self):
        if self.__experience > 3:
            # Senior instructors need feedback of 4.5 or more
            return self.__avg_feedback >= 4.5
        else:
            # Junior instructors need feedback of 4.0 or more
            return self.__avg_feedback >= 4.0

    # Check if a course with the given technology can be assigned to this instructor
    def allocate_course(self, technology):
        # First check if instructor is eligible at all
        if not self.check_eligibility():
            return False
        # Then check if instructor has the required technology skill
        return technology.lower() in [skill.lower() for skill in self.__technology_skills]

# %%
instructors_data = [
    {
        "name": "Sohail",
        "skills": ["Python", "Machine Learning", "Data Science"],
        "experience": 5,
        "feedback": 4.7,   # eligible: >3 yrs and feedback >= 4.5
    },
    {
        "name": "Imran",
        "skills": ["Java", "Spring Boot", "Microservices"],
        "experience": 5,
        "feedback": 4.2,   # not eligible: >3 yrs but feedback < 4.5
    },
    {
        "name": "Amish",
        "skills": ["JavaScript", "React", "Node.js"],
        "experience": 2,
        "feedback": 4.1,   # eligible: <=3 yrs and feedback >= 4.0
    },
    {
        "name": "Usman",
        "skills": ["C++", "Embedded Systems"],
        "experience": 1,
        "feedback": 3.8,   # not eligible: <=3 yrs but feedback < 4.0
    },
]

test_courses = ["Python", "Java", "React", "C++"]

# --- Testing ---

for data in instructors_data:
    # Create instructor object and set values using setter methods
    inst = Instructor()
    inst.set_name(data["name"])
    inst.set_technology_skills(data["skills"])
    inst.set_experience(data["experience"])
    inst.set_avg_feedback(data["feedback"])

    # Display instructor info
    print(f"\nInstructor : {inst.get_name()}")
    print(f"Skills     : {', '.join(inst.get_technology_skills())}")
    print(f"Experience : {inst.get_experience()} yr(s) | Feedback: {inst.get_avg_feedback()}")
    print(f"Eligible   : {inst.check_eligibility()}")

    # Test course allocation for each course
    print("Course Allocation:")
    for course in test_courses:
        result = inst.allocate_course(course)
        print(f"  {course}: {result}")
# Out:
# Instructor : Sohail
# Skills     : Python, Machine Learning, Data Science
# Experience : 5 yr(s) | Feedback: 4.7
# Eligible   : True
# Course Allocation:
#   Python: True
#   Java: False
#   React: False
#   C++: False
#
# Instructor : Imran
# Skills     : Java, Spring Boot, Microservices
# Experience : 5 yr(s) | Feedback: 4.2
# Eligible   : False
# Course Allocation:
#   Python: False
#   Java: False
#   React: False
#   C++: False
#
# Instructor : Amish
# Skills     : JavaScript, React, Node.js
# Experience : 2 yr(s) | Feedback: 4.1
# Eligible   : True
# Course Allocation:
#   Python: False
#   Java: False
#   React: True
#   C++: False
#
# Instructor : Usman
# Skills     : C++, Embedded Systems
# Experience : 1 yr(s) | Feedback: 3.8
# Eligible   : False
# Course Allocation:
#   Python: False
#   Java: False
#   React: False
#   C++: False
